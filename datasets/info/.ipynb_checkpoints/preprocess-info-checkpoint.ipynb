# %%
import pandas as pd
import numpy as np
import re

# %% [markdown]
# # mountain station

# %% [markdown]
# http://www2.nsysu.edu.tw/Mountain/trick/coordinates.htm

# %%
mou_info = pd.read_csv('mou-station-info')
mou_info = mou_info[mou_info.SiteName.isin(['牧山','大霸尖山','玉山','北大武山'])]
mou_info['SiteEngName'] = ['Yushan','Dabajianshan','Mushan','Beidawushan']
mou_info = mou_info[['SiteName','SiteEngName','lat','lon']]
mou_info['area'] = 'mou'
mou_info
# Out:
#    SiteName   SiteEngName        lat         lon area
# 0        玉山        Yushan  23.470556  120.948889  mou
# 26     大霸尖山  Dabajianshan  24.461111  121.249722  mou
# 66       牧山        Mushan  23.864722  121.152222  mou
# 92     北大武山   Beidawushan  22.629167  120.751944  mou

# %% [markdown]
# # epa station

# %%
epa_info = pd.read_csv('epa-station-info')
epa_info['area'] = 'city'
epa_info.head()
# Out:
#   SiteName SiteEngName AreaName County Township      SiteAddress         lon  \
# 0       陽明    Yangming    北部空品區    臺北市      北投區   臺北市北投區竹子湖路111號  121.529583
# 1       萬里       Wanli    北部空品區    新北市      萬里區    新北市萬里區瑪鋉路221號  121.689881
# 2       淡水      Tamsui    北部空品區    新北市      淡水區  新北市淡水區中正東路42巷6號  121.449239
# 3       基隆     Keelung    北部空品區    基隆市      信義區    基隆市信義區東信路324號  121.760056
# 4       士林      Shilin    北部空品區    臺北市      北投區   臺北市北投區文林北路155號  121.514500
#
#          lat SiteType  lat_round  lon_round  row  col  area
# 0  25.182722     公園測站      25.18     121.53   16  153  city
# 1  25.179667     一般測站      25.18     121.69   16  169  city
# 2  25.164500     一般測站      25.16     121.45   18  145  city
# 3  25.129167     一般測站      25.13     121.76   21  176  city
# 4  25.105917     一般測站      25.11     121.51   23  151  city

# %% [markdown]
# # combine station

# %%
import os
import sys
home=os.path.expanduser("~")
sys.path.append(os.path.join(home, 'station2grid'))
from tools.knn_model import KnnModel
from tools.options import *
from tools import datasets

# %%
optionS2GSD = OptionS2GSD()
dataS2G = datasets.DataS2G(optionS2GSD)
model = KnnModel(dataS2G)

# %%
sta_info = epa_info.append(mou_info, sort=False)
sta_info['lat_round'] = sta_info.lat.apply(lambda x: round(x,2))
sta_info['lon_round'] = sta_info.lon.apply(lambda x: round(x,2))
sta_info.loc[67, 'lat_round'] = 22.60 # 前鎮

sta_info['row'] = sta_info.lat_round.apply(lambda x: [round(y,2) for y in model.lats].index(x))
sta_info['col'] = sta_info.lon_round.apply(lambda x: [round(y,2) for y in model.lons].index(x))

sta_info = sta_info.sort_values(by=['area','lat',],ascending=False).reset_index(drop=True)
sta_info = sta_info[['SiteName',
                     'SiteEngName',
                     'lat',
                     'lon',
                     'lat_round',
                     'lon_round',
                     'row',
                     'col']]
sta_info
sta_info.to_csv('station-info',index=False)

# %%
pd.read_csv('station-info')
# Out:
#    SiteName   SiteEngName        lat         lon  lat_round  lon_round  row  \
# 0      大霸尖山  Dabajianshan  24.461111  121.249722      24.46     121.25   88
# 1        牧山        Mushan  23.864722  121.152222      23.86     121.15  148
# 2        玉山        Yushan  23.470556  120.948889      23.47     120.95  187
# 3      北大武山   Beidawushan  22.629167  120.751944      22.63     120.75  271
# 4        陽明      Yangming  25.182722  121.529583      25.18     121.53   16
# 5        萬里         Wanli  25.179667  121.689881      25.18     121.69   16
# 6        淡水        Tamsui  25.164500  121.449239      25.16     121.45   18
# 7        基隆       Keelung  25.129167  121.760056      25.13     121.76   21
# 8        士林        Shilin  25.105917  121.514500      25.11     121.51   23
# 9        林口        Linkou  25.078570  121.365703      25.08     121.37   26
# 10       三重      Sanchong  25.072611  121.493806      25.07     121.49   27
# 11       菜寮       Cailiao  25.068950  121.481028      25.07     121.48   27
# 12       汐止         Xizhi  25.065669  121.640800      25.07     121.64   27
# 13       大同        Datong  25.063200  121.513311      25.06     121.51   28
# 14       中山     Zhongshan  25.062361  121.526528      25.06     121.53   28
# 15       大園        Dayuan  25.060344  121.201811      25.06     121.20   28
# 16       松山      Songshan  25.050000  121.578611      25.05     121.58   29
# 17       萬華        Wanhua  25.046503  121.507972      25.05     121.51   29
# 18       新莊     Xinzhuang  25.037972  121.432500      25.04     121.43   30
# 19       觀音       Guanyin  25.035503  121.082761      25.04     121.08   30
# 20       古亭        Guting  25.020608  121.529556      25.02     121.53   32
# 21       永和        Yonghe  25.017000  121.516306      25.02     121.52   32
# 22       板橋       Banqiao  25.012972  121.458667      25.01     121.46   33
# 23       桃園       Taoyuan  24.995667  121.304417      25.00     121.30   34
# 24       土城       Tucheng  24.982528  121.451861      24.98     121.45   36
# 25       新店       Xindian  24.977222  121.537778      24.98     121.54   36
# 26       平鎮      Pingzhen  24.954208  121.204981      24.95     121.20   39
# 27       中壢       Zhongli  24.953278  121.221667      24.95     121.22   39
# 28       湖口         Hukou  24.900142  121.038653      24.90     121.04   44
# 29       龍潭       Longtan  24.863869  121.216350      24.86     121.22   48
# ..      ...           ...        ...         ...        ...        ...  ...
# 47       南投        Nantou  23.913000  120.685306      23.91     120.69  143
# 48       崙背        Lunbei  23.757547  120.348742      23.76     120.35  158
# 49       竹山       Zhushan  23.756389  120.677306      23.76     120.68  158
# 50       麥寮       Mailiao  23.753506  120.251825      23.75     120.25  159
# 51       臺西         Taixi  23.717533  120.202842      23.72     120.20  162
# 52       斗六        Douliu  23.711853  120.544994      23.71     120.54  163
# 53       新港       Xingang  23.554839  120.345531      23.55     120.35  179
# 54       朴子          Puzi  23.465308  120.247350      23.47     120.25  187
# 55       嘉義        Chiayi  23.462778  120.440833      23.46     120.44  188
# 56       新營       Xinying  23.305633  120.317250      23.31     120.32  203
# 57       善化       Shanhua  23.115097  120.297142      23.12     120.30  222
# 58       安南         Annan  23.048333  120.218333      23.05     120.22  229
# 59       關山      Guanshan  23.045083  121.161933      23.05     121.16  229
# 60       臺南        Tainan  22.984581  120.202617      22.98     120.20  236
# 61       美濃       Meinong  22.883583  120.530542      22.88     120.53  246
# 62       橋頭       Qiaotou  22.757506  120.305689      22.76     120.31  258
# 63       臺東       Taitung  22.755358  121.150450      22.76     121.15  258
# 64       楠梓         Nanzi  22.733667  120.328289      22.73     120.33  261
# 65       仁武         Renwu  22.689056  120.332631      22.69     120.33  265
# 66       左營       Zuoying  22.674861  120.292917      22.67     120.29  267
# 67       屏東      Pingtung  22.673081  120.488033      22.67     120.49  267
# 68       前金       Qianjin  22.632567  120.288086      22.63     120.29  271
# 69       鳳山      Fengshan  22.627392  120.358083      22.63     120.36  271
# 70       復興        Fuxing  22.608711  120.312017      22.61     120.31  273
# 71       前鎮      Qianzhen  22.605386  120.307564      22.60     120.31  274
# 72       小港      Xiaogang  22.565833  120.337736      22.57     120.34  277
# 73       大寮        Daliao  22.564136  120.425311      22.56     120.43  278
# 74       潮州      Chaozhou  22.523108  120.561175      22.52     120.56  282
# 75       林園       Linyuan  22.479500  120.411750      22.48     120.41  286
# 76       恆春      Hengchun  21.958069  120.788928      21.96     120.79  338
#
#     col
# 0   125
# 1   115
# 2    95
# 3    75
# 4   153
# 5   169
# 6   145
# 7   176
# 8   151
# 9   137
# 10  149
# 11  148
# 12  164
# 13  151
# 14  153
# 15  120
# 16  158
# 17  151
# 18  143
# 19  108
# 20  153
# 21  152
# 22  146
# 23  130
# 24  145
# 25  154
# 26  120
# 27  122
# 28  104
# 29  122
# ..  ...
# 47   69
# 48   35
# 49   68
# 50   25
# 51   20
# 52   54
# 53   35
# 54   25
# 55   44
# 56   32
# 57   30
# 58   22
# 59  116
# 60   20
# 61   53
# 62   31
# 63  115
# 64   33
# 65   33
# 66   29
# 67   49
# 68   29
# 69   36
# 70   31
# 71   31
# 72   34
# 73   43
# 74   56
# 75   41
# 76   79
#
# [77 rows x 8 columns]
