# %%
import pandas as pd
import numpy as np
import os
home=os.path.expanduser("~")

import sys 
sys.path.append(os.path.join(os.path.expanduser("~"),'station2grid'))
from tools import CustomKNN

# %% [markdown]
# # input csv

# %%
epaStationInfo=pd.read_csv(os.path.join(home,'station2grid','datasets','info','epa-station-info.csv'))
epaStationInfo
# Out:
#    SiteName SiteEngName AreaName County Township        SiteAddress  \
# 0        陽明    Yangming    北部空品區    臺北市      北投區     臺北市北投區竹子湖路111號
# 1        萬里       Wanli    北部空品區    新北市      萬里區      新北市萬里區瑪鋉路221號
# 2        淡水      Tamsui    北部空品區    新北市      淡水區    新北市淡水區中正東路42巷6號
# 3        基隆     Keelung    北部空品區    基隆市      信義區      基隆市信義區東信路324號
# 4        士林      Shilin    北部空品區    臺北市      北投區     臺北市北投區文林北路155號
# 5        林口      Linkou    北部空品區    新北市      林口區   新北市林口區文化北路1段425號
# 6        三重    Sanchong    北部空品區    新北市      三重區    新北市三重區三和路與重陽路交口
# 7        菜寮     Cailiao    北部空品區    新北市      三重區     新北市三重區中正北路163號
# 8        汐止       Xizhi    北部空品區    新北市      汐止區  新北市汐止區樟樹一路137巷26號
# 9        大同      Datong    北部空品區    臺北市      大同區     臺北市大同區重慶北路3段2號
# 10       中山   Zhongshan    北部空品區    臺北市      中山區     臺北市中山區林森北路511號
# 11       大園      Dayuan    北部空品區    桃園市      大園區     桃園市大園區中正東路160號
# 12       松山    Songshan    北部空品區    臺北市      松山區    臺北市松山區八德路4段746號
# 13       萬華      Wanhua    北部空品區    臺北市      萬華區     臺北市萬華區中華路1段66號
# 14       新莊   Xinzhuang    北部空品區    新北市      新莊區      新北市新莊區中正路510號
# 15       觀音     Guanyin    北部空品區    桃園市      觀音區        桃園市觀音區文化路2號
# 16       古亭      Guting    北部空品區    臺北市      大安區   臺北市大安區羅斯福路3段201號
# 17       永和      Yonghe    北部空品區    新北市      永和區    新北市永和區永和路與光復路交口
# 18       板橋     Banqiao    北部空品區    新北市      板橋區     新北市板橋區文化路1段25號
# 19       桃園     Taoyuan    北部空品區    桃園市      桃園區       桃園市桃園區莒光街15號
# 20       土城     Tucheng    北部空品區    新北市      土城區    新北市土城區學府路1段241號
# 21       新店     Xindian    北部空品區    新北市      新店區      新北市新店區民族路108號
# 22       平鎮    Pingzhen    北部空品區    桃園市      平鎮區       桃園市平鎮區復興街55號
# 23       中壢     Zhongli    北部空品區    桃園市      中壢區      桃園市中壢區延平路622號
# 24       湖口       Hukou    竹苗空品區    新竹縣      湖口鄉      新竹縣湖口鄉成功路360號
# 25       龍潭     Longtan    北部空品區    桃園市      龍潭區      桃園市龍潭區中正路210號
# 26       新竹     Hsinchu    竹苗空品區    新竹市       東區        新竹市東區民族路33號
# 27       宜蘭       Yilan    宜蘭空品區    宜蘭縣      宜蘭市     宜蘭縣宜蘭市復興路二段77號
# 28       竹東     Zhudong    竹苗空品區    新竹縣      竹東鎮    新竹縣竹東鎮榮樂里三民街70號
# 29       頭份      Toufen    竹苗空品區    苗栗縣      頭份鎮       苗栗縣頭份市文化街20號
# ..      ...         ...      ...    ...      ...                ...
# 43       南投      Nantou    中部空品區    南投縣      南投市      南投縣南投市南陽路269號
# 44       崙背      Lunbei   雲嘉南空品區    雲林縣      崙背鄉       雲林縣崙背鄉大成路91號
# 45       竹山     Zhushan    中部空品區    南投縣      竹山鎮      南投縣竹山鎮大明路666號
                 how='left')
oneYear=oneYear[['dt','lat','lon','station','feature','value']]
oneYear.head()
# Out:
#                     dt        lat         lon station   feature  value
# 0  2015-01-01 00:00:00  24.900142  121.038653      湖口  AMB_TEMP   16.0
# 1  2015-01-01 01:00:00  24.900142  121.038653      湖口  AMB_TEMP   15.0
# 2  2015-01-01 02:00:00  24.900142  121.038653      湖口  AMB_TEMP   15.0
# 3  2015-01-01 03:00:00  24.900142  121.038653      湖口  AMB_TEMP   14.0
# 4  2015-01-01 04:00:00  24.900142  121.038653      湖口  AMB_TEMP   14.0

# %%
oneYear.feature.unique()
# Out:
# array(['AMB_TEMP', 'PM10', 'PM2.5', 'RH'], dtype=object)

# %%
dts=oneYear.dt.unique()
features=oneYear.feature.unique()

# %%
dt=dts[48]
feature=features[1]
oneDtFea=oneYear[(oneYear.dt==dt)&(oneYear.feature==feature)]
oneDtFea
# Out:
#                        dt      lat         lon station feature  value
# 3288  2015-01-03 00:00:00  25.1645  121.449239      淡水    PM10   26.0
# 6668  2015-01-03 00:00:00  25.0632  121.513311      大同    PM10   50.0

# %%
oneDtFea.value.values.shape

# %%
customKNN=CustomKNN()
x_train=oneDtFea[['lat','lon']].values
y_train=oneDtFea.value.values
k=1
weightKNN='distance'
x_test=epaStationInfo[['lat','lon']].values
y_test=customKNN.get_knn(k,weightKNN,x_train,y_train,x_test)
y_test.shape

# %% [markdown]
# # script

# %%
customKNN=CustomKNN()
epaStationInfo=pd.read_csv(os.path.join(home,'station2grid','datasets','info','epa-station-info.csv'))

def get_oneYear(year):
    csv_path=os.path.join(home,'station2grid','datasets','csv','epa','epa%s.csv'%(year))
    oneYear=pd.read_csv(csv_path)
    oneYear=pd.merge(left=oneYear,
                     right=epaStationInfo[['SiteName','lat','lon']],
                     left_on='station',
                     right_on='SiteName',
                     how='left')
    oneYear=oneYear[['dt','lat','lon','station','feature','value']]
    return oneYear

def get_oneDtArr(oneDt,features):
    oneDtArr=[]
    for feature in features:
        oneDtFea=oneDt[oneDt.feature==feature]
        x_train=oneDtFea[['lat','lon']].values
        y_train=oneDtFea.value.values
        k,weightKNN=1,'distance'
        x_test=epaStationInfo[['lat','lon']].values
        y_test=customKNN.get_knn(k,weightKNN,x_train,y_train,x_test)
        y_test=y_test.reshape(1,-1,1)
        oneDtArr.append(y_test)
    oneDtArr=np.concatenate(oneDtArr,axis=-1)    
    return oneDtArr

def saveFeatures(features):
    path=os.path.join(self.home,'station2grid','datasets','info','epa-features.csv')
    dummy=pd.DataFrame({'feature':features})
    dummy.to_csv(path)

def get_allDtArr(oneYear):
    dts=oneYear.dt.unique()
    features=oneYear.feature.unique()
    
    featureDic={'AMB_TEMP':'temperature', 'PM10':'pm10', 'PM2.5':'pm25', 'RH':'humidity'}
    features_=[featureDic[fea] for fea in features]
#     print(features_)
    saveFeatures(features)
    
    allDtArr=[]
    for i,dt in enumerate(dts[:]):
        oneDt=oneYear[oneYear.dt==dt]
        if len(oneDt.feature.unique())<len(features): continue
        oneDtArr=get_oneDtArr(oneDt,features)
        allDtArr.append(oneDtArr)
    allDtArr=np.concatenate(allDtArr,axis=0)
    return allDtArr
    
oneYear=get_oneYear(2014)
allDtArr=get_allDtArr(oneYear)
allDtArr.shape
# Out:
# ['temperature', 'pm10', 'pm25', 'humidity']
# (48, 73, 4)

# %%
pm25
pm10
temperature
humidity
